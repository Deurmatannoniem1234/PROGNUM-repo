# %% [markdown]
# # Practice BS

# %%
#this is a test
#Hello
"""
This is a test
here you can explain whatever the fuck you want
Yay, Fun!
"""
print("test")
# Out:
# test

# %% [markdown]
# $$E_f = \frac{h \cdot c}{\lambda}$$

# %% [markdown]
# $$x = \sin{y}$$

# %% [markdown]
# # 2.5
# $$\sum^{\infty}_{k=0}\frac{1}{4k^2-1}=\frac{1}{2}$$
# $$\int^{x}_{0}e^{ix}dx=2i$$

# %%
from IPython.display import display, Math
from math import sin, pi

x = 9
Lambda = 0.5

s = rf"\sqrt({x}) = {x**0.5}\ and \sin(\lambda \pi)={sin(Lambda*pi)}"
print(s)
m = Math(s)
display(m)
# Out:
# \sqrt(9) = 3.0\ and \sin(\lambda \pi)=1.0
# $\displaystyle \sqrt(9) = 3.0\ and \sin(\lambda \pi)=1.0$

# %%
from math import factorial as fact
x=fact(100)
print(x)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
from math import atan2, degrees, atan
x=float(input("Give the value for x:"))
y=float(input("Give the value for y:"))
Slope=y/x
Angle=degrees(atan(Slope))
Angle2=degrees(atan2(y,x))
if x>=0 and y>0:
    print(f"the line is in Quadrant 1 with an Angle of {Angle2} Degrees")
elif x<0 and y>=0:
    print(f"the line is in Quadrant 2 with an Angle of {Angle2} Degrees")
elif x<=0 and y<0:
    print(f"the line is in Quadrant 3 with an Angle of {Angle2} Degrees")
elif x>0 and y<=0:
    print(f"the line is in Quadrant 4 with an Angle of {Angle2} Degrees")
# Out:
# Give the value for x: 2
# Give the value for y: 3
# the line is in Quadrant 1 with an Angle of 56.309932474020215 Degrees

# %% [markdown]
# atan is normal $tan^{-1}$ and atan2 is the angle to the x axis given from only x,y values, as a vector

# %% [markdown]
# # Check from here
# # 2.14

# %%
x = [1.36,  1.46,  1.41,  2.12,  0.42,  0.98,  0.45,  1.97, -0.24, 2.18]
x.append(0.51) 
x.remove(2.12)

print(f"The number corresponding to index = 6 is {x[6]}")

for i in range(len(x)):
    if x[i] == 1.46:
        print(f"The index number for x = 1.46 is {i}.")

y = slice(2,len(x)-2,2)
sumy = round(sum(x[y]),2)

print(f"All even numbers from index 2 except the last one:{x[y]} with the sum of: {sumy}.")
# Out:
# The number corresponding to index = 6 is 1.97
# The index number for x = 1.46 is 1.
# All even numbers from index 2 except the last one:[1.41, 0.98, 1.97] with the sum of: 4.36.

# %% [markdown]
# # 2.15

# %%
night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]

y1 = set(night1)
y2 = set(night2)

z=list(y1.intersection(y2))
print(f"the common numbers are {z}")
for i in range(len(z)):
    if z[i] == 5:
        print(f"5 is a value in this list at index {i}")
    elif i == (len(z)-1):
        print(f"5 was not in both nights")

if 5 in y1:
    print("5 is a number in night 1")
# Out:
# the common numbers are [0, 1, 2, 3, 4]
# 5 was not in both nights
# 5 is a number in night 1

# %% [markdown]
# # 2.19

# %%
import numpy as np
import matplotlib.pyplot as plt

mu, sigma = 0, 1.4 #Mean, Standard Div
s = np.random.normal(mu, sigma, 100000)
a = round(np.std(s),1)
print(a)
# Out:
# 1.4

# %% [markdown]
# # 2.21

# %%
i=1
x = [1,2]
while i < 99:
    i+=1
    x.append(x[i-2]+x[i-1])
print(f"the 100th fibonachi number is: {x[99]}")
# Out:
# the 100th fibonachi number is: 573147844013817084101

# %% [markdown]
# # 2.26

# %% [markdown]
# ![Screenshot_20260219_142312.png](attachment:6693ffc8-aa73-460b-bf30-1610ff13857e.png)
