# %% [markdown]
# * Name: Mattanja Gerritsen
# * Username: mgerritsen
# * Student s-number: S6325084
# * Group (AS1, etc.): AS4

# %%
x = 22/7
print(x)
# Out:
# 3.142857142857143

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub
print(pi)
# Out:
# 3.142857142857143

# %% [markdown]
# ![Shappo0.jpg](attachment:89eb5345-2000-4271-887f-a61c3d524594.jpg)

# %%
from scipy.constants import G

Mmoon=7.342e22
Mearth=5.9722e24
r=385000.6

F_g=(G*Mmoon*Mearth)/(r**2)
print(F_g)
# Out:
# 1.9743840518075714e+26

# %% [markdown]
# ![Screenshot 2026-02-10 144518.png](attachment:89e96d9e-4342-46ce-a0c9-b07af0fce8a8.png)

# %% [markdown]
# ![1.11.png](attachment:89a0fe3b-9b15-4fba-beea-5813ab06266a.png)
