# %% [markdown]
# # Session Quizzes Week 4

# %% [markdown]
# # 4.1

# %%
x = [1,2,3,10]    #define lists:
y = [10, 20, 30, 40] 
#Zip them

z = list(zip(x,y))

print(z)

a = [z[i][0]+z[i][1] for i in range(len(z))]
print(a)



def count(list):
    value = list[0]+list[1]
    return value

q = list(map(count, z))
print(q)
# Out:
# [(1, 10), (2, 20), (3, 30), (10, 40)]
# [11, 22, 33, 50]
# [11, 22, 33, 50]

# %% [markdown]
# # Random bs

# %%
import numpy as np

dice = [np.random.randint(1,7) for x in range(120)]
print(dice.count(6))
# Out:
# 20

# %% [markdown]
# # 4.3

# %%
import numpy as np

RPS = input("Rock, paper or Scissor? (give R, P or S)")
Comp = np.random.randint(1,4) #Generate the Computer Awnser

#Convert Awnser to number Rock = 1, Paper = 2, Scissor = 3
if RPS == "R":
    RPS = 1
elif RPS == "P":
    RPS = 2
elif RPS == "S":
    RPS = 3
else:
    print("That is not R, P or S")
    
#Who Won?
if RPS == Comp:
    print(f"you tied!")
elif RPS - Comp == 1 or RPS == 1 and Comp == 3:
    print(f"You Won!")
elif Comp - RPS == 1 or Comp == 1 and RPS == 3:
    print(f"You Lost :(")
# Out:
# Rock, paper or Scissor? (give R, P or S) R
# You Won!

# %% [markdown]
# # 4.4

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy 

Data=np.random.normal(185,8,100000)
X = float(input("What amount of cm do you know the propability of:"))

print(f"The chance of being {X} cm tall or smaller is :{scipy.stats.norm.cdf(X, 185, 8)*100}%")
P1STD = abs(scipy.stats.norm.cdf(177, 185, 8)-scipy.stats.norm.cdf(193, 185, 8))
print(f"The chance of being inside the 1 STD limit is {P1STD*100:.2f}%")

plt.hist(Data,40, label = f"Mean: {np.mean(Data):.0f}, and STD: {np.std(Data):.0f}")
plt.legend(fontsize=8)
plt.axvline(185, color="r", linestyle = "--")
plt.axvspan(177, 193, color="red", alpha=0.3, label="Area under curve")
plt.show
# Out:
# What amount of cm do you know the propability of: 185
# The chance of being 185.0 cm tall or smaller is :50.0%
# The chance of being inside the 1 STD limit is 68.27%
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 4.6 NEEDS WORK!

# %%
from scipy.integrate import quad
import numpy as np

scale = 5; loc=185

def f(x, scale, loc):
    return norm.pdf(Func, scale=scale, loc=loc)

Func = input("Give function, x for example")
# Get user input for limits
a = float(input("Give the lower limit: "))
b = float(input("Give the higher limit: "))

# Use quad to integrate
probability, error = quad(f, a, b, args=(scale, loc))

print(f"The probability between {a} and {b} is: {probability:.4f}")
# Out:
# Give function, x for example x
# Give the lower limit:  0
# Give the higher limit:  5
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[91], line 15
#      12 b = float(input("Give the higher limit: "))
#      14 # Use quad to integrate
# ---> 15 probability, error = quad(f, a, b, args=(scale, loc))
#      17 print(f"The probability between {a} and {b} is: {probability:.4f}")
#
# File /Software/users/modules/9/software/anaconda3/2025.06/lib/python3.13/site-packages/scipy/integrate/_quadpack_py.py:460, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst, complex_func)
#     457     return retval
#     459 if weight is None:
# --> 460     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     461                    points)
#     462 else:
#     463     if points is not None:
#
# File /Software/users/modules/9/software/anaconda3/2025.06/lib/python3.13/site-packages/scipy/integrate/_quadpack_py.py:607, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     605 if points is None:
#     606     if infbounds == 0:
# --> 607         return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     608     else:
#     609         return _quadpack._qagie(func, bound, infbounds, args, full_output,
#     610                                 epsabs, epsrel, limit)
#
# Cell In[91], line 7, in f(x, scale, loc)
#       6 def f(x, scale, loc):
# ----> 7     return norm.pdf(Func, scale=scale, loc=loc)
#
# File /Software/users/modules/9/software/anaconda3/2025.06/lib/python3.13/site-packages/scipy/stats/_distn_infrastructure.py:2065, in rv_continuous.pdf(self, x, *args, **kwds)
#    2063 args = tuple(map(asarray, args))
#    2064 dtyp = np.promote_types(x.dtype, np.float64)
# -> 2065 x = np.asarray((x - loc)/scale, dtype=dtyp)
#    2066 cond0 = self._argcheck(*args) & (scale > 0)
#    2067 cond1 = self._support_mask(x, *args) & (scale > 0)
#
# UFuncTypeError: ufunc 'subtract' did not contain a loop with signature matching types (dtype('<U1'), dtype('int64')) -> None
